# %%
# Out:
# /Users/joonyoo/Desktop/Code/LearnPython/UCSDSAN2019DATA1/01-Lesson-Plans/05-Matplotlib/1/Activities/08-Stu_PyBars/Solved

# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis, bars_in_cities, color="b", align="center")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, cities)
# Out:
# ([<matplotlib.axis.XTick at 0x11ed1ab38>,
#   <matplotlib.axis.XTick at 0x11ed1a4a8>,
#   <matplotlib.axis.XTick at 0x11ea02ba8>,
#   <matplotlib.axis.XTick at 0x11ed771d0>,
#   <matplotlib.axis.XTick at 0x11ed77668>],
#  <a list of 5 Text xticklabel objects>)

# %%
# Set the limits of the x axis
plt.xlim(-1, len(x_axis)-0.25)
# Out:
# (-1, 4.75)

# %%
# Set the limits of the y axis
plt.ylim(0, max(bars_in_cities)+0.4)
# Out:
# (0, 9.0)

# %%
# Give the chart a title, x label, and y label
plt.title("Density of Bars in Cities")
plt.xlabel("Cities")
plt.ylabel("Bars Per 10,000 Households")
# Out:
# Text(61.44444598754247, 0.5, 'Bars Per 10,000 Households')

# %%
# Save an image of the chart and print it to the screen
plt.savefig("BarDensity.png")
plt.show()

# %% [markdown]
# (BarDensity.png)
