# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_df = pd.read_csv("../Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
len(rain_df)
# Out:
# 50

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
plt.tight_layout()

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(7,5))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="699.999984827909">
# ([<matplotlib.axis.XTick at 0x121e87a58>,
#   <matplotlib.axis.XTick at 0x121e87320>,
#   <matplotlib.axis.XTick at 0x121e6af98>,
#   <matplotlib.axis.XTick at 0x1225bfb70>,
#   <matplotlib.axis.XTick at 0x1225d04a8>,
#   <matplotlib.axis.XTick at 0x1225d0978>,
#   <matplotlib.axis.XTick at 0x1225d0e48>,
#   <matplotlib.axis.XTick at 0x1225d7358>,
#   <matplotlib.axis.XTick at 0x1225d7828>,
#   <matplotlib.axis.XTick at 0x1225d7cf8>,
#   <matplotlib.axis.XTick at 0x1225df240>,
#   <matplotlib.axis.XTick at 0x1225d7dd8>,
#   <matplotlib.axis.XTick at 0x1225d0550>,
#   <matplotlib.axis.XTick at 0x1225df048>,
#   <matplotlib.axis.XTick at 0x1225dfbe0>,
#   <matplotlib.axis.XTick at 0x1225e6160>,
#   <matplotlib.axis.XTick at 0x1225e6630>,
#   <matplotlib.axis.XTick at 0x1225e6b38>,
#   <matplotlib.axis.XTick at 0x1225f10f0>,
#   <matplotlib.axis.XTick at 0x1225f1588>,
#   <matplotlib.axis.XTick at 0x1225e6710>,
#   <matplotlib.axis.XTick at 0x1225dfa58>,
#   <matplotlib.axis.XTick at 0x1225f1748>,
#   <matplotlib.axis.XTick at 0x1225f1eb8>,
#   <matplotlib.axis.XTick at 0x1225f9400>,
#   <matplotlib.axis.XTick at 0x1225f9908>,
#   <matplotlib.axis.XTick at 0x1225f9e10>,
#   <matplotlib.axis.XTick at 0x122601358>,
#   <matplotlib.axis.XTick at 0x122601860>,
#   <matplotlib.axis.XTick at 0x122601d68>,
#   <matplotlib.axis.XTick at 0x1226016d8>,
#   <matplotlib.axis.XTick at 0x1225df320>,
#   <matplotlib.axis.XTick at 0x12260a240>,
#   <matplotlib.axis.XTick at 0x12260a748>,
#   <matplotlib.axis.XTick at 0x12260ac50>,
#   <matplotlib.axis.XTick at 0x122611198>,
#   <matplotlib.axis.XTick at 0x1226116a0>,
#   <matplotlib.axis.XTick at 0x122611ba8>,
#   <matplotlib.axis.XTick at 0x12261a160>,
#   <matplotlib.axis.XTick at 0x122611240>,
#   <matplotlib.axis.XTick at 0x12260a0b8>,
#   <matplotlib.axis.XTick at 0x12261a438>,
#   <matplotlib.axis.XTick at 0x12261a940>,
#   <matplotlib.axis.XTick at 0x12261ae48>,
#   <matplotlib.axis.XTick at 0x122622390>,
#   <matplotlib.axis.XTick at 0x122622898>,
#   <matplotlib.axis.XTick at 0x122622da0>,
#   <matplotlib.axis.XTick at 0x1226292e8>,
#   <matplotlib.axis.XTick at 0x122622e80>,
#   <matplotlib.axis.XTick at 0x12261a4e0>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(59.94444616635641, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
#plt.tight_layout()
plt.savefig("../Images/avg_state_rain.png")
plt.show()
